# %%
import pandas as pd

# %%
# 2 main datatypes  (series=> 1D)
series=pd.Series(["BMW","TOYOTA","HONDA"])

# %%
series
# Out:
# 0       BMW
# 1    TOYOTA
# 2     HONDA
# dtype: object

# %%
colour=pd.Series(["RED","BLUE","WHITE"])

# %%
colour
# Out:
# 0      RED
# 1     BLUE
# 2    WHITE
# dtype: object

# %%
#data frame-> 2D
car_data=pd.DataFrame({"car ": series, "colour":colour})

# %%
car_data
# Out:
#     car  colour
# 0    RED    RED
# 1   BLUE   BLUE
# 2  WHITE  WHITE

# %%
#import data
car_sales=pd.read_csv("car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#exporting to dataframe
car_sales.to_csv("exported_car_sales.csv", index=False)

# %%
exported_car_sales=pd.read_csv("exported_car_sales.csv")
exported_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fuel per 100 km  \
# 0  Toyota  White      93776.875      4   400000    5.0              7.5
# 1   Honda    Red      54936.875      4   500000    5.0              9.2
# 2  Toyota   Blue      20343.125      3   700000    5.0              5.0
# 3     Bmw  Black       6986.875      5  2200000    5.0              9.6
# 4  Nissan  White     133184.375      4   350000    5.0              8.7
# 5  Toyota  Green      62008.125      4   450000    5.0              4.7
# 6   Honda   Blue      28561.250      4   750000    5.0              7.6
# 7   Honda   Blue      34211.250      4   700000    5.0              8.7
# 8  Toyota  White      37500.000      4   625000    5.0              3.0
# 9  Nissan  White      19750.000      4   970000    5.0              4.5
#
#    number of wheels  passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# ...

# %%
heart_disease = pd.read_csv("https://raw.githubusercontent.com/mrdbourke/zero-to-mastery-ml/master/data/heart-disease.csv")

# %%
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# ##Descibe data

# %%
# attribute (dtype attribute is some meta info which stored about the car sale dataframe)
car_sales.dtypes
# function (going to perform some steps)
#car_sales.to_csv()
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_columns=car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
#describe works only on numeric columns
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_prices=pd.Series([300,1500,32450])
car_prices.mean(numeric_only=True)
# Out:
# 11416.666666666666

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
#for single columns
car_sales["Doors"].sum()
# Out:
# 40

# %%
len(car_sales)
# Out:
# 10

# %%
car_prices=pd.Series([300,1500,32450])
car_prices.sum()
# Out:
# 34250

# %%
car_prices=pd.Series([300,1500,32450])
car_prices.max()
# Out:
# 32450

# %% [markdown]
# ##Viewing and delecting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# .loc & .iloc
animals=pd.Series(["cat","dog","panda","bird","snake"], index=[0,3,9,8,3])
animals
# Out:
# 0      cat
# 3      dog
# 9    panda
# 8     bird
# 3    snake
# dtype: object

# %%
## loc refers to index numbers
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[9]
# Out:
# 'panda'

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# .iloc refers to position
animals.iloc[3]
# Out:
# 'bird'

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
#slicing
animals.iloc[:3]
# Out:
# 0      cat
# 3      dog
# 9    panda
# dtype: object

# %%
car_sales.iloc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales.loc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
#dot notation will give error if there is any space ex:- odometer (km)
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales["Make"]=="BMW"]
# Out:
#   Make Colour  Odometer (KM)  Doors       Price
# 3  BMW  Black          11179      5  $22,000.00

# %%
car_sales[car_sales["Odometer (KM)"]>100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
#groupby
car_sales.groupby(["Make"]).sum()
# Out:
#                      Colour  Odometer (KM)  Doors  \
# Make
# BMW                   Black          11179      5
# Honda           RedBlueBlue         188335     12
# Nissan           WhiteWhite         244695      8
# Toyota  WhiteBlueGreenWhite         341805     15
#
#                                        Price
# Make
# BMW                               $22,000.00
# Honda            $5,000.00$7,500.00$7,000.00
# Nissan                    $3,500.00$9,700.00
# Toyota  $4,000.00$7,000.00$4,500.00$6,250.00

# %%
car_sales.groupby(["Make"]).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\Desktop\sample_project\env\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~\Desktop\sample_project\env\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\Desktop\sample_project\env\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
# ...

# %%
plot only numeric values

# %%
# %matplotlib inline #===============================================================================================
import matplotlib.pyplot as plt

# %%
car_sales["Doors"].plot()
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
#pehle iska dtype 'o' matlab object tha
car_sales["Price"].dtype
# Out:
# dtype('int32')

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,]|\.\d*', '').astype(int)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\NAYAB\AppData\Local\Temp\ipykernel_11244\735999026.py:1: SyntaxWarning: invalid escape sequence '\$'
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,]|\.\d*', '').astype(int)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[148], line 1
# ----> 1 car_sales["Price"] = car_sales["Price"].str.replace('[\$\,]|\.\d*', '').astype(int)
#
# File ~\Desktop\sample_project\env\Lib\site-packages\pandas\core\generic.py:6296, in NDFrame.__getattr__(self, name)
#    6289 if (
#    6290     name not in self._internal_names_set
#    6291     and name not in self._metadata
#    6292     and name not in self._accessors
#    6293     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294 ):
#    6295     return self[name]
# ...

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %%
car_data
# Out:
#     car  colour
# 0    RED    RED
# 1   BLUE   BLUE
# 2  WHITE  WHITE

# %%
Price=pd.Series(["$1000","$1200","$3000"])

# %%
car_data=pd.DataFrame({"car ": series, "colour":colour,"Price":Price})

# %%
car_data
# Out:
#     car  colour  Price
# 0    RED    RED  $1000
# 1   BLUE   BLUE  $1200
# 2  WHITE  WHITE  $3000

# %%
car_data
# Out:
#     car  colour  Price
# 0    RED    RED   1000
# 1   BLUE   BLUE   1200
# 2  WHITE  WHITE   3000

# %%
car_data["Price"].plot()
# Out:
# <Axes: >

# %%
xyz=pd.Series(["$100","$120","$300"])

# %%
-xyz
# Out:
# 0    $100
# 1    $120
# 2    $300
# dtype: object

# %%
car_data=pd.DataFrame({"car ": series, "colour":colour,"xyz":xyz})

# %%
car_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 car_data
#
# NameError: name 'car_data' is not defined

# %%
car_data["xyz"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[143], line 1
# ----> 1 car_data["xyz"].plot()
#
# File ~\Desktop\sample_project\env\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\Desktop\sample_project\env\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\Desktop\sample_project\env\Lib\site-packages\pandas\plotting\_matplotlib\core.py:499, in MPLPlot.generate(self)
#     497 @final
# ...

# %%
car_data["xyz"] = car_data["xyz"].str.replace('[\$\,]|\.\d*', '',regex=True).astype(int)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\NAYAB\AppData\Local\Temp\ipykernel_13128\3098833862.py:1: SyntaxWarning: invalid escape sequence '\$'
#   car_data["xyz"] = car_data["xyz"].str.replace('[\$\,]|\.\d*', '',regex=True).astype(int)
# C:\Users\NAYAB\AppData\Local\Temp\ipykernel_13128\3098833862.py:1: SyntaxWarning: invalid escape sequence '\$'
#   car_data["xyz"] = car_data["xyz"].str.replace('[\$\,]|\.\d*', '',regex=True).astype(int)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 car_data["xyz"] = car_data["xyz"].str.replace('[\$\,]|\.\d*', '',regex=True).astype(int)
#
# NameError: name 'car_data' is not defined

# %%
car_data["xyz"].plot()
# Out:
# <Axes: >

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$,]|(\.\d*)', '', regex=True).astype(int)
#car_sales["Price"] = car_sales["Price"].astype(str)
#car_sales["Price"] = car_sales["Price"].str.replace(r'[\$,]|(\.\d*)', '', regex=True).astype(int)
#car_sales
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# C:\Users\NAYAB\AppData\Local\Temp\ipykernel_11244\4012101928.py:1: SyntaxWarning: invalid escape sequence '\$'
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$,]|(\.\d*)', '', regex=True).astype(int)
# C:\Users\NAYAB\AppData\Local\Temp\ipykernel_11244\4012101928.py:1: SyntaxWarning: invalid escape sequence '\$'
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$,]|(\.\d*)', '', regex=True).astype(int)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[151], line 1
# ----> 1 car_sales["Price"] = car_sales["Price"].str.replace('[\$,]|(\.\d*)', '', regex=True).astype(int)
#
# File ~\Desktop\sample_project\env\Lib\site-packages\pandas\core\generic.py:6296, in NDFrame.__getattr__(self, name)
#    6289 if (
# ...

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## decimal points removed

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %% [markdown]
# ##MANIPULATING DATA

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   400000
# 1   honda    Red          87899      4   500000
# 2  toyota   Blue          32549      3   700000
# 3     bmw  Black          11179      5  2200000
# 4  nissan  White         213095      4   350000
# 5  toyota  Green          99213      4   450000
# 6   honda   Blue          45698      4   750000
# 7   honda   Blue          54738      4   700000
# 8  toyota  White          60000      4   625000
# 9  nissan  White          31600      4   970000

# %%
car_sales["Make"] = car_sales["Make"].str.capitalize()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     Bmw  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
#missing data denoted with NaN
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean()
# Out:
# 115554.0

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"] = car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean())

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing
# Out:
# C:\Users\NAYAB\AppData\Local\Temp\ipykernel_11244\3265876450.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales_missing["Odometer"] = car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"]=car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(),inplace=False)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing= pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped=car_sales_missing.dropna()
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv("car-sales-missing-dropped.csv")

# %%
# column from series
seats_column= pd.Series([5,5,5,5,5])

#new column called seats
car_sales["seats"] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats
# 0  Toyota  White         150043      4   400000    5.0
# 1   Honda    Red          87899      4   500000    5.0
# 2  Toyota   Blue          32549      3   700000    5.0
# 3     Bmw  Black          11179      5  2200000    5.0
# 4  Nissan  White         213095      4   350000    5.0
# 5  Toyota  Green          99213      4   450000    NaN
# 6   Honda   Blue          45698      4   750000    NaN
# 7   Honda   Blue          54738      4   700000    NaN
# 8  Toyota  White          60000      4   625000    NaN
# 9  Nissan  White          31600      4   970000    NaN

# %%
car_sales["seats"].fillna(5, inplace=True)
car_sales
# Out:
# C:\Users\NAYAB\AppData\Local\Temp\ipykernel_11244\3880422171.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_sales["seats"].fillna(5, inplace=True)
#      Make Colour  Odometer (KM)  Doors    Price  seats
# 0  Toyota  White         150043      4   400000    5.0
# 1   Honda    Red          87899      4   500000    5.0
# 2  Toyota   Blue          32549      3   700000    5.0
# 3     Bmw  Black          11179      5  2200000    5.0
# 4  Nissan  White         213095      4   350000    5.0
# ...

# %%
#column from python list
fuel_economy = [7.5,9.2,5.0,9.6,8.7,4.7,7.6,8.7,3.0,4.5]
car_sales["fuel per 100 km"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fuel per 100 km
# 0  Toyota  White         150043      4   400000    5.0              7.5
# 1   Honda    Red          87899      4   500000    5.0              9.2
# 2  Toyota   Blue          32549      3   700000    5.0              5.0
# 3     Bmw  Black          11179      5  2200000    5.0              9.6
# 4  Nissan  White         213095      4   350000    5.0              8.7
# 5  Toyota  Green          99213      4   450000    5.0              4.7
# 6   Honda   Blue          45698      4   750000    5.0              7.6
# 7   Honda   Blue          54738      4   700000    5.0              8.7
# 8  Toyota  White          60000      4   625000    5.0              3.0
# 9  Nissan  White          31600      4   970000    5.0              4.5

# %%
car_sales["total fuel used"] = car_sales["Odometer (KM)"]/100*car_sales["fuel per 100 km"]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fuel per 100 km  \
# 0  Toyota  White         150043      4   400000    5.0              7.5
# 1   Honda    Red          87899      4   500000    5.0              9.2
# 2  Toyota   Blue          32549      3   700000    5.0              5.0
# 3     Bmw  Black          11179      5  2200000    5.0              9.6
# 4  Nissan  White         213095      4   350000    5.0              8.7
# 5  Toyota  Green          99213      4   450000    5.0              4.7
# 6   Honda   Blue          45698      4   750000    5.0              7.6
# 7   Honda   Blue          54738      4   700000    5.0              8.7
# 8  Toyota  White          60000      4   625000    5.0              3.0
# 9  Nissan  White          31600      4   970000    5.0              4.5
#
#    total fuel used
# 0        11253.225
# 1         8086.708
# 2         1627.450
# 3         1073.184
# 4        18539.265
# 5         4663.011
# 6         3473.048
# ...

# %%
#create column from single value
car_sales["number of wheels"]=4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fuel per 100 km  \
# 0  Toyota  White         150043      4   400000    5.0              7.5
# 1   Honda    Red          87899      4   500000    5.0              9.2
# 2  Toyota   Blue          32549      3   700000    5.0              5.0
# 3     Bmw  Black          11179      5  2200000    5.0              9.6
# 4  Nissan  White         213095      4   350000    5.0              8.7
# 5  Toyota  Green          99213      4   450000    5.0              4.7
# 6   Honda   Blue          45698      4   750000    5.0              7.6
# 7   Honda   Blue          54738      4   700000    5.0              8.7
# 8  Toyota  White          60000      4   625000    5.0              3.0
# 9  Nissan  White          31600      4   970000    5.0              4.5
#
#    total fuel used  number of wheels
# 0        11253.225                 4
# 1         8086.708                 4
# 2         1627.450                 4
# ...

# %%
car_sales["passed road safety"]=True
car_sales.dtypes
# Out:
# Make                   object
# Colour                 object
# Odometer (KM)           int64
# Doors                   int64
# Price                   int32
# seats                 float64
# fuel per 100 km       float64
# total fuel used       float64
# number of wheels        int64
# passed road safety       bool
# dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fuel per 100 km  \
# 0  Toyota  White         150043      4   400000    5.0              7.5
# 1   Honda    Red          87899      4   500000    5.0              9.2
# 2  Toyota   Blue          32549      3   700000    5.0              5.0
# 3     Bmw  Black          11179      5  2200000    5.0              9.6
# 4  Nissan  White         213095      4   350000    5.0              8.7
# 5  Toyota  Green          99213      4   450000    5.0              4.7
# 6   Honda   Blue          45698      4   750000    5.0              7.6
# 7   Honda   Blue          54738      4   700000    5.0              8.7
# 8  Toyota  White          60000      4   625000    5.0              3.0
# 9  Nissan  White          31600      4   970000    5.0              4.5
#
#    total fuel used  number of wheels  passed road safety
# 0        11253.225                 4                True
# 1         8086.708                 4                True
# ...

# %%
car_sales.drop("total fuel used", axis=1)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fuel per 100 km  \
# 0  Toyota  White         150043      4   400000    5.0              7.5
# 1   Honda    Red          87899      4   500000    5.0              9.2
# 2  Toyota   Blue          32549      3   700000    5.0              5.0
# 3     Bmw  Black          11179      5  2200000    5.0              9.6
# 4  Nissan  White         213095      4   350000    5.0              8.7
# 5  Toyota  Green          99213      4   450000    5.0              4.7
# 6   Honda   Blue          45698      4   750000    5.0              7.6
# 7   Honda   Blue          54738      4   700000    5.0              8.7
# 8  Toyota  White          60000      4   625000    5.0              3.0
# 9  Nissan  White          31600      4   970000    5.0              4.5
#
#    number of wheels  passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fuel per 100 km  \
# 0  Toyota  White         150043      4   400000    5.0              7.5
# 1   Honda    Red          87899      4   500000    5.0              9.2
# 2  Toyota   Blue          32549      3   700000    5.0              5.0
# 3     Bmw  Black          11179      5  2200000    5.0              9.6
# 4  Nissan  White         213095      4   350000    5.0              8.7
# 5  Toyota  Green          99213      4   450000    5.0              4.7
# 6   Honda   Blue          45698      4   750000    5.0              7.6
# 7   Honda   Blue          54738      4   700000    5.0              8.7
# 8  Toyota  White          60000      4   625000    5.0              3.0
# 9  Nissan  White          31600      4   970000    5.0              4.5
#
#    total fuel used  number of wheels  passed road safety
# 0        11253.225                 4                True
# 1         8086.708                 4                True
# ...

# %%
car_sales=car_sales.drop("total fuel used", axis=1)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fuel per 100 km  \
# 0  Toyota  White         150043      4   400000    5.0              7.5
# 1   Honda    Red          87899      4   500000    5.0              9.2
# 2  Toyota   Blue          32549      3   700000    5.0              5.0
# 3     Bmw  Black          11179      5  2200000    5.0              9.6
# 4  Nissan  White         213095      4   350000    5.0              8.7
# 5  Toyota  Green          99213      4   450000    5.0              4.7
# 6   Honda   Blue          45698      4   750000    5.0              7.6
# 7   Honda   Blue          54738      4   700000    5.0              8.7
# 8  Toyota  White          60000      4   625000    5.0              3.0
# 9  Nissan  White          31600      4   970000    5.0              4.5
#
#    number of wheels  passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# ...

# %%
car_sales.sample(frac=0.5)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fuel per 100 km  \
# 5  Toyota  Green          99213      4   450000    5.0              4.7
# 6   Honda   Blue          45698      4   750000    5.0              7.6
# 7   Honda   Blue          54738      4   700000    5.0              8.7
# 3     Bmw  Black          11179      5  2200000    5.0              9.6
# 1   Honda    Red          87899      4   500000    5.0              9.2
#
#    number of wheels  passed road safety
# 5                 4                True
# 6                 4                True
# 7                 4                True
# 3                 4                True
# 1                 4                True

# %%
car_sales_shuffled=car_sales.sample(frac=1)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fuel per 100 km  \
# 3     Bmw  Black          11179      5  2200000    5.0              9.6
# 2  Toyota   Blue          32549      3   700000    5.0              5.0
# 8  Toyota  White          60000      4   625000    5.0              3.0
# 6   Honda   Blue          45698      4   750000    5.0              7.6
# 5  Toyota  Green          99213      4   450000    5.0              4.7
# 7   Honda   Blue          54738      4   700000    5.0              8.7
# 0  Toyota  White         150043      4   400000    5.0              7.5
# 4  Nissan  White         213095      4   350000    5.0              8.7
# 1   Honda    Red          87899      4   500000    5.0              9.2
# 9  Nissan  White          31600      4   970000    5.0              4.5
#
#    number of wheels  passed road safety
# 3                 4                True
# 2                 4                True
# 8                 4                True
# ...

# %%
# 20% data
car_sales_shuffled.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  seats  fuel per 100 km  \
# 2  Toyota   Blue          32549      3  700000    5.0              5.0
# 9  Nissan  White          31600      4  970000    5.0              4.5
#
#    number of wheels  passed road safety
# 2                 4                True
# 9                 4                True

# %%
#car_sales_shuffled.reset_index(inplace=True)
car_sales_shuffled.reset_index(drop=True, inplace=True)

# %%
car_sales_shuffled.reset_index(drop=True, inplace=True)
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fuel per 100 km  \
# 0     Bmw  Black          11179      5  2200000    5.0              9.6
# 1  Toyota   Blue          32549      3   700000    5.0              5.0
# 2  Toyota  White          60000      4   625000    5.0              3.0
# 3   Honda   Blue          45698      4   750000    5.0              7.6
# 4  Toyota  Green          99213      4   450000    5.0              4.7
# 5   Honda   Blue          54738      4   700000    5.0              8.7
# 6  Toyota  White         150043      4   400000    5.0              7.5
# 7  Nissan  White         213095      4   350000    5.0              8.7
# 8   Honda    Red          87899      4   500000    5.0              9.2
# 9  Nissan  White          31600      4   970000    5.0              4.5
#
#    number of wheels  passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fuel per 100 km  \
# 0  Toyota  White         150043      4   400000    5.0              7.5
# 1   Honda    Red          87899      4   500000    5.0              9.2
# 2  Toyota   Blue          32549      3   700000    5.0              5.0
# 3     Bmw  Black          11179      5  2200000    5.0              9.6
# 4  Nissan  White         213095      4   350000    5.0              8.7
# 5  Toyota  Green          99213      4   450000    5.0              4.7
# 6   Honda   Blue          45698      4   750000    5.0              7.6
# 7   Honda   Blue          54738      4   700000    5.0              8.7
# 8  Toyota  White          60000      4   625000    5.0              3.0
# 9  Nissan  White          31600      4   970000    5.0              4.5
#
#    number of wheels  passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# ...

# %%
#lambda keyword in python short for ananimous function,  1.6(conversion from km to miles)
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x/1.6)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  seats  fuel per 100 km  \
# 0  Toyota  White      93776.875      4   400000    5.0              7.5
# 1   Honda    Red      54936.875      4   500000    5.0              9.2
# 2  Toyota   Blue      20343.125      3   700000    5.0              5.0
# 3     Bmw  Black       6986.875      5  2200000    5.0              9.6
# 4  Nissan  White     133184.375      4   350000    5.0              8.7
# 5  Toyota  Green      62008.125      4   450000    5.0              4.7
# 6   Honda   Blue      28561.250      4   750000    5.0              7.6
# 7   Honda   Blue      34211.250      4   700000    5.0              8.7
# 8  Toyota  White      37500.000      4   625000    5.0              3.0
# 9  Nissan  White      19750.000      4   970000    5.0              4.5
#
#    number of wheels  passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# ...
